# %%
# Download and install the tweepy Module
# The below code shuld be run in your terminal on your computer and not through this

#pip install tweepy

# %%
# SYSTEM SETUP

# Filenmae and hashtags you're looking for
fetched_tweets_filename = "Python_Module_Semester_two.csv"
hash_tag_list = ["UCD", "Engineering"]

#Login Details - These should be contained within a seperate file in order to be hidden
Consumer_Key = "5pyLheXVTQP6YMJV8grmd5A4V"
Consumer_Secret = "Ygug7Nf8zHHSk6ybnSwFoS2beph9Gk0rmy65rOqaLotxDNfXNZ"
Access_Token = "831913807194767362-1vq7LIWgxCVmqwybrNGoG1n8aQbsd3J"
Access_Secret = "tRkQYAW2Nx7Emaqeh8vOmx1wWQiaIyzPQj4q9fY1gbktf"

# %%
# Import a class from the tweepy module that allows me to listen to the tweets
from tweepy.streaming import StreamListener

# Import authentification class
from tweepy import OAuthHandler

#
from tweepy import Stream

# %%
# # # # TWITTER STREAMER # # # #
class TwitterStreamer():
    """
    Class for streaming and processing live tweets.
    """
    def __init__(self):
        pass

    def stream_tweets(self, fetched_tweets_filename, hash_tag_list):
        # This handles Twitter authetification and the connection to Twitter Streaming API
        listener = StdOutListener(fetched_tweets_filename)
        auth = OAuthHandler(Consumer_Key, Consumer_Secret)
        auth.set_access_token(Access_Token,Access_Secret)
        stream = Stream(auth, listener)

        # This line filter Twitter Streams to capture data by the keywords: 
        stream.filter(track=hash_tag_list)

# %%
# # # # TWITTER STREAM LISTENER # # # #
class StdOutListener(StreamListener):
    """
    This is a basic listener that just prints received tweets to stdout.
    """
    def __init__(self, fetched_tweets_filename):
        self.fetched_tweets_filename = fetched_tweets_filename

    def on_data(self, data):
        try:
            print(data)
            with open(self.fetched_tweets_filename, 'a') as tf:
                tf.write(data)
            return True
        except BaseException as e:
            print("Error on_data %s" % str(e))
        return True
          

    def on_error(self, status):
        print(status)

 
if __name__ == '__main__':
 
    # Authenticate using config.py and connect to Twitter Streaming API.
    twitter_streamer = TwitterStreamer()
    twitter_streamer.stream_tweets(fetched_tweets_filename, hash_tag_list)
# Out:
# {"created_at":"Wed Mar 13 20:32:56 +0000 2019","id":1105929757445767168,"id_str":"1105929757445767168","text":"RT @NASA: Engineering and physics degrees? \u2705 Previous work for us? \u2705 Experience working at the South Pole and America Samoa? \u2705 Find out why\u2026","source":"\u003ca href=\"http:\/\/twitter.com\/download\/iphone\" rel=\"nofollow\"\u003eTwitter for iPhone\u003c\/a\u003e","truncated":false,"in_reply_to_status_id":null,"in_reply_to_status_id_str":null,"in_reply_to_user_id":null,"in_reply_to_user_id_str":null,"in_reply_to_screen_name":null,"user":{"id":1021370963454300161,"id_str":"1021370963454300161","name":"\u0938\u094d\u092f\u093e\u0928\u0926\u093e\u0907\u2122\ufe0f","screen_name":"Syaandai","location":null,"url":null,"description":"\u201c\u0938\u094d\u0935\u0924\u0928\u094d\u0924\u094d\u0930\u0924\u093e \u092d\u0928\u094d\u0928\u093e\u0932\u0947 \u091c\u0939\u093f\u0932\u0947 \u092a\u0928\u093f (\u0906\u092b\u0942\u092d\u0928\u094d\u0926\u093e) \u092b\u0930\u0
# ...

# %%
#Now we must read that file and turn all the jumpled up data into an excel file with useeful data
# First read the file: check out lecture notes 5 page 18

import pandas as pd
df = pd.read_csv(fetched_tweets_filename)

# Read out the o'th row
#df.iloc[0]

# add row to CSV file
import csv
with open(fetched_tweets_filename, "a", newline='') as f:
    writer = csv.DictWriter(f, fieldnames=header)
    writer.writerow(myDict)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-fe1be57f09a2> in <module>
#      11 import csv
#      12 with open(fetched_tweets_filename, "a", newline='') as f:
# ---> 13     writer = csv.DictWriter(f, fieldnames=header)
#      14     writer.writerow(myDict)
#
# NameError: name 'header' is not defined
